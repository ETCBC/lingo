# %%
from tf.app import use

# %%
A = use("bhsa", hoist=globals())
# Out:
# Using etcbc/bhsa/tf - c r1.5 in /Users/dirk/text-fabric-data
# Using etcbc/phono/tf - c r1.2 in /Users/dirk/text-fabric-data
# Using etcbc/parallels/tf - c r1.2 in /Users/dirk/text-fabric-data
# ...

# %%
q = "word gn=f"

# %%
results = A.search(q)
# Out:
#   0.45s 36720 results

# %%
A.table(results, start=1, end=100, condenseType="clause", linked=2)
# Out:
# n | word
# --- | ---
# 1|<span class="hb">רֵאשִׁ֖ית </span>
# 2|<span class="hb">הָיְתָ֥ה </span>
# 3|<span class="hb">תְהֹ֑ום </span>
# 4|<span class="hb">מְרַחֶ֖פֶת </span>
# 5|<span class="hb">תֵרָאֶ֖ה </span>
# 6|<span class="hb">יַּבָּשָׁ֑ה </span>
# 7|<span class="hb">יַּבָּשָׁה֙ </span>
# 8|<span class="hb">תַּֽדְשֵׁ֤א </span>
# 9|<span class="hb">תֹּוצֵ֨א </span>
# 10|<span class="hb">אֹתֹת֙ </span>
# 11|<span class="hb">שָׁנִֽים׃ </span>
# 12|<span class="hb">מֶמְשֶׁ֣לֶת </span>
# 13|<span class="hb">מֶמְשֶׁ֣לֶת </span>
# 14|<span class="hb">נֶ֣פֶשׁ </span>
# 15|<span class="hb">חַיָּ֑ה </span>
# 16|<span class="hb">נֶ֣פֶשׁ </span>
# 17|<span class="hb">חַיָּ֣ה׀ </span>
# 18|<span class="hb">רֹמֶ֡שֶׂת </span>
# 19|<span class="hb">כָּנָף֙ </span>
# 20|<span class="hb">תֹּוצֵ֨א </span>
# 21|<span class="hb">נֶ֤פֶשׁ </span>
# 22|<span class="hb">חַיָּה֙ </span>
# 23|<span class="hb">בְּהֵמָ֥ה </span>
# 24|<span class="hb">חַֽיְתֹו־</span>
# 25|<span class="hb">חַיַּ֨ת </span>
# ...
